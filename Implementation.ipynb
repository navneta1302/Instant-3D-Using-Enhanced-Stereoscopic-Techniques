# %%
pip install mpl_stereo
# Out:
# Requirement already satisfied: mpl_stereo in c:\users\navaneetha\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: matplotlib>=3.8.2 in c:\users\navaneetha\anaconda3\lib\site-packages (from mpl_stereo) (3.8.4)
# Requirement already satisfied: numpy>=1.26 in c:\users\navaneetha\anaconda3\lib\site-packages (from mpl_stereo) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\navaneetha\anaconda3\lib\site-packages (from matplotlib>=3.8.2->mpl_stereo) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\navaneetha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.2->mpl_stereo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mpl_stereo import AxesStereo2D, AxesStereo3D, AxesAnaglyph
from mpl_stereo.example_data import trefoil
x, y, z = trefoil()
axstereo = AxesStereo2D()
axstereo.plot(x, y, z, c='k', alpha=0.2)
axstereo.scatter(x, y, z, c=z, cmap='viridis', s=10)
# Out:
# (<matplotlib.collections.PathCollection at 0x1f3aa42b5c0>,
#  <matplotlib.collections.PathCollection at 0x1f3aa42b8c0>)

# %%
axstereo = AxesStereo3D()
axstereo.plot(x, y, z, c='k', alpha=0.2)
axstereo.scatter(x, y, z, c=z, cmap='viridis', s=10)
# Out:
# (<mpl_toolkits.mplot3d.art3d.Path3DCollection at 0x1f3aabf40b0>,
#  <mpl_toolkits.mplot3d.art3d.Path3DCollection at 0x1f3aabcbdd0>)

# %%
axstereo =AxesAnaglyph()
axstereo.plot(x, y, z)
axstereo.scatter(x, y, z, s=10)
# Out:
# (<matplotlib.collections.PathCollection at 0x1f3abccbaa0>,
#  <matplotlib.collections.PathCollection at 0x1f3abe1e330>)

# %%
from mpl_stereo.example_data import sun_left_right
sun_left_data, sun_right_data =sun_left_right()
axstereo=AxesStereo2D()
axstereo.ax_left.imshow(sun_left_data,cmap='gray')
axstereo.ax_right.imshow(sun_right_data,cmap='gray')

# %%
axstereo=AxesAnaglyph()
axstereo.imshow_stereo(sun_left_data,sun_right_data,cmap='gray')

# %%
from IPython.display import Image
Image(filename='sun_wiggle.gif')
